# %% [markdown]
# # 1.Package Import

# %%
from bmovie_code import gen_table1_subj_info
from pynwb import NWBHDF5IO
from pathlib import Path
import numpy as np
import pandas as pd

from new_code import data_summary, load_data_into_pds, load_data_into_dict, slicer, label, feature, decompose, fusion, new_fusion

import pickle
from scipy.signal import detrend

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # 2. Global file location (need to specify your own path)

# %%
NWB_DIR="/Volumes/Extreme SSD/GT/PSYC8803/data/bmovie/nwb_files"
BIDS_DIR="/Volumes/Extreme SSD/GT/PSYC8803/data/bmovie/bids_files"

# %%
gen_table1_subj_info.main(
    nwb_input_dir=NWB_DIR,
    bids_datadir=BIDS_DIR
)

# %% [markdown]
# # 3. Load labels and data

# %%
# labels
with open("../assets/annotations/short_faceannots.pkl", "rb") as f:
    face_annots = pickle.load(f)

type(face_annots)
# print(list(face_annots.items())[:10])

path = "../assets/annotations/scenecut_info.csv"
scenecut_info = pd.read_csv(path)

print(scenecut_info.head())
# Out:
#    scene_id  shot_start_fr  shot_start_t  shot_dur_t  location cut_type  \
# 0       1.0            1.0          0.00        4.72  backyard      cut
# 1       1.0          119.0          4.72       10.28  backyard      cut
# 2       1.0          376.0         15.00        1.72  backyard      cut
# 3       1.0          419.0         16.72        2.36  backyard      cut
# 4       1.0          478.0         19.08        2.64  backyard      cut
#
#    cut_dur_t  cut_dur_fr
# 0        0.0           0
# 1        0.0           0
# 2        0.0           0
# 3        0.0           0
# 4        0.0           0

# %%
df_face_note = label.build_face_feature_df(face_annots, target_id="Jacky")
print(df_face_note.tail())
# Out:
#         frame_key  frame_idx  movie_time  n_faces  total_face_area  \
# 9373  frame_11898      11898      475.92        2      35470.00073
# 9374  frame_11899      11899      475.96        2      35470.00073
# 9375  frame_11900      11900      476.00        2      35470.00073
# 9376  frame_11901      11901      476.04        2      35470.00073
# 9377  frame_11902      11902      476.08        2      35470.00073
#
#       max_face_area  Jacky_present  any_front_face dominant_emotion  \
# 9373   24058.686485              0               1        surprised
# 9374   24058.686485              0               1        surprised
# 9375   24058.686485              0               1        surprised
# 9376   24058.686485              0               1        surprised
# 9377   24058.686485              0               1        surprised
#
#       emo_afraid  emo_angry  emo_happy  emo_neutral  emo_surprised
# 9373       False      False      False        False           True
# 9374       False      False      False        False           True
# 9375       False      False      False        False           True
# 9376       False      False      False        False           True
# 9377       False      False      False        False           True

# %% [markdown]
# ## 3.1 Label Check

# %%
import matplotlib.pyplot as plt

emo_cols = [
    "emo_afraid",
    "emo_angry",
    "emo_happy",
    "emo_neutral",
    "emo_surprised"
]

t = df_face_note["movie_time"].values

# ===================================
# face emotion label check
# ===================================
plt.figure(figsize=(6, 3))

for i, col in enumerate(emo_cols):
    y = df_face_note[col].astype(int) * (i + 1)
    plt.scatter(t, y, s=5, label=col)

plt.axvline(0, color="black", linestyle="--")
plt.yticks(range(1, len(emo_cols)+1), emo_cols)
plt.ylim(0.5, len(emo_cols)+0.5)
plt.xlabel("Time (s)")
plt.title("Emotion labels over time")
plt.legend(bbox_to_anchor=(1.0,0), loc="lower left", frameon=False)
plt.show()

# ===================================
# face emotion switching
# ===================================
is_non_neutral = ~df_face_note["emo_neutral"]

plt.figure(figsize=(6, 3))
plt.plot(t, is_non_neutral.astype(int), linewidth=1)

plt.xlabel("Time (s)")
plt.ylabel("Non-neutral (1)")
plt.title("Neutral vs Non-neutral switching")
plt.ylim(-0.1, 1.1)
plt.show()

# ===================================
# distribution check
# ===================================
labels = df_face_note["dominant_emotion"].values

segments = []
start = 0

for i in range(1, len(labels)):
    if labels[i] != labels[i-1]:
        segments.append((labels[i-1], start, i-1))
        start = i

segments.append((labels[-1], start, len(labels)-1))

lengths = [end - start + 1 for (_, start, end) in segments]

plt.figure(figsize=(6, 3))
plt.hist(lengths, bins=50)
plt.xlabel("Segment length (frames)")
plt.ylabel("Count")
plt.title("Distribution of label segment length")
plt.show()

print("median:", np.median(lengths))
print("short (<5 frames):", np.mean(np.array(lengths) < 5))

# ===================================
# screen check
# ===================================

lengths = np.array(lengths)

thresholds = np.arange(1, 30)
proportion = [(lengths >= th).mean() for th in thresholds]

plt.figure(figsize=(6, 3))
plt.plot(thresholds, proportion)
plt.xlabel("Min segment length (frames)")
plt.ylabel("Proportion kept")
plt.title("Data retained vs segment length threshold")
plt.show()
# Out:
# median: 47.0
# short (<5 frames): 0.0

# %%
import matplotlib.pyplot as plt

t = df_face_note["movie_time"].values

jacky = df_face_note["Jacky_present"].astype(int).values
front = df_face_note["any_front_face"].astype(int).values

plt.figure(figsize=(6, 2))

plt.scatter(t[jacky == 1], [1]*np.sum(jacky==1), s=2, label="Jacky_present")
plt.scatter(t[front == 1], [0]*np.sum(front==1), s=2, label="any_front_face")

plt.yticks([0, 1], ["Front Face", "Jacky"])
plt.xlabel("Time (s)")
plt.title("Face presence raster")
plt.legend(bbox_to_anchor=(1.0,0), loc="lower left", frameon=False)
plt.show()

# %%
nwb_path = load_data_into_pds.find_nwb_file_for_subject(NWB_DIR, "CS41")
print("Using:", nwb_path)

io = NWBHDF5IO(str(nwb_path), "r", load_namespaces=True)
nwb = io.read()

print("\n=== acquisition keys ===")
print(list(nwb.acquisition.keys()))

print("\n=== processing modules ===")
print(list(nwb.processing.keys()))

for mod_name, mod in nwb.processing.items():
    print(f"\n--- processing[{mod_name}] keys ---")
    try:
        print(list(mod.data_interfaces.keys()))
    except Exception as e:
        print("cannot list data_interfaces:", e)

print("\n=== stimulus keys ===")
print(list(getattr(nwb, "stimulus", {}).keys()))

print("\n=== intervals ===")
print(list(getattr(nwb, "intervals", {}).keys()))

io.close()
# Out:
# Using: /Volumes/Extreme SSD/GT/PSYC8803/data/bmovie/nwb_files/000623/sub-CS41/sub-CS41_ses-P41CSR1_behavior+ecephys.nwb
#
# === acquisition keys ===
# ['events_ttl', 'experiment_ids']
#
# === processing modules ===
# ['behavior', 'ecephys']
#
# --- processing[behavior] keys ---
# ['Blink', 'EyeTracking', 'Fixation', 'PupilTracking', 'Saccade']
#
# --- processing[ecephys] keys ---
# ['LFP_macro', 'LFP_micro']
#
# === stimulus keys ===
# ['movieframe_time']
#
# === intervals ===
# ['trials']

# %%
from pynwb import NWBHDF5IO
io = NWBHDF5IO("/Volumes/Extreme SSD/GT/PSYC8803/data/bmovie/nwb_files/000623/sub-CS41/sub-CS41_ses-P41CSR1_behavior+ecephys.nwb", "r", load_namespaces=True)
nwb = io.read()

ece = nwb.processing["ecephys"]
print("LFP_macro electrical_series keys:", list(ece["LFP_macro"].electrical_series.keys()))
print("LFP_micro electrical_series keys:", list(ece["LFP_micro"].electrical_series.keys()))

beh = nwb.processing["behavior"]
print("EyeTracking spatial_series keys:", list(beh["EyeTracking"].spatial_series.keys()))
print("PupilTracking time_series keys:", list(beh["PupilTracking"].time_series.keys()))

io.close()
# Out:
# LFP_macro electrical_series keys: ['ElectricalSeries']
# LFP_micro electrical_series keys: ['ElectricalSeries']
# EyeTracking spatial_series keys: ['SpatialSeries']
# PupilTracking time_series keys: ['TimeSeries']

# %%
sub_nums = [41, 42, 43, 44, 45]
filter_config = {
    "lfp_macro": {"type": "bandpass", "low": 0.5, "high": 150.0, "order": 4},
    "lfp_micro": {"type": "bandpass", "low": 0.5, "high": 300.0, "order": 4},
    "eye_gaze":  {"type": "lowpass",  "high": 20.0, "order": 4},
    "pupil":     {"type": "lowpass",  "high": 10.0, "order": 4},
}

data = load_data_into_dict.load_multimodal_subjects_movie_aligned(
    sub_nums=sub_nums,
    nwb_root=NWB_DIR,
    bids_root=BIDS_DIR,
    max_nwb_samples=2000000,
    b_filter_data=True,
    filter_config=filter_config,
    
    grid_source= "lfp_raw",   # {"movie_frame_time", "uniform", "lfp_raw"}
    grid_dt = None,         # used when grid_source == "uniform"
    uniform_grid_include_baseline = True,

    compute_firing_rate= True,
    firing_rate_bin_width= None,  # if None, infer from t_grid
    compute_lfp_bandpower= True,
    lfp_bandpower_on_raw= True,       # recommended
    bands= None,

    # optional fmri
    load_fmri= False,
    fmri_max_runs= None,
)

print(data[41].keys())
print(data[41]['meta'])
print(data[41]["lfp_macro"].shape, data[41]["eye_gaze"].shape)
# print("n_units:", data[41]["meta"]["n_units"], "firing_rate:", data[41]["firing_rate"].shape)
print("band keys:", list(data[41]["lfp_bandpower"].keys()))
# data[41]["lfp_macro"][:, :5]
x = data[41]["lfp_macro"]
t = data[41]["time_grid"]
print(x.shape, len(t))
# Out:
# [sub 41] nwb_path=/Volumes/Extreme SSD/GT/PSYC8803/data/bmovie/nwb_files/000623/sub-CS41/sub-CS41_ses-P41CSR1_behavior+ecephys.nwb
# [sub 41] fs_macro=1000.0, fs_micro=1000.0, fs_eye=499.9999999976126
# [sub 41] t_macro_movie range=(-10.000, 753.963)
# [sub 41] movieframe_time(frame) range=(0.000, 11970.000)
# [sub 41] movieframe_time_sec range=(0.000, 478.800)
# [sub 41] t_grid len=763964 source=lfp_raw
# [sub 42] nwb_path=/Volumes/Extreme SSD/GT/PSYC8803/data/bmovie/nwb_files/000623/sub-CS42/sub-CS42_ses-P42CSR1_behavior+ecephys.nwb
# [sub 42] fs_macro=1000.0, fs_micro=1000.0, fs_eye=499.9999999976126
# [sub 42] t_macro_movie range=(-10.000, 814.068)
# [sub 42] movieframe_time(frame) range=(0.000, 11970.000)
# [sub 42] movieframe_time_sec range=(0.000, 478.800)
# [sub 42] t_grid len=824069 source=lfp_raw
# [sub 43] nwb_path=/Volumes/Extreme SSD/GT/PSYC8803/data/bmovie/nwb_files/000623/sub-CS43/sub-CS43_ses-P43CSR1_behavior+ecephys.nwb
# [sub 43] fs_macro=1000.0, fs_micro=1000.0, fs_eye=499.9999999976126
# [sub 43] t_macro_movie range=(-9.999, 823.868)
# [sub 43] movieframe_time(frame) range=(0.000, 11970.000)
# [sub 43] movieframe_time_sec range=(0.000, 478.800)
# [sub 43] t_grid len=833868 source=lfp_raw
# [sub 44] nwb_path=/Volumes/Extreme SSD/GT/PSYC8803/data/bmovie/nwb_files/000623/sub-CS44/sub-CS44_ses-P44CSR1_behavior+ecephys.nwb
# [sub 44] fs_macro=1000.0, fs_micro=1000.0, fs_eye=499.9999999976126
# [sub 44] t_macro_movie range=(-9.999, 887.859)
# [sub 44] movieframe_time(frame) range=(0.000, 11970.000)
# [sub 44] movieframe_time_sec range=(0.000, 478.800)
# [sub 44] t_grid len=897859 source=lfp_raw
# dict_keys(['spikes', 'firing_rate', 'lfp_macro', 'lfp_micro', 'lfp_bandpower', 'eye_gaze', 'pupil', 'time_grid', 'movieframe_time', 'movieframe_time_sec', 'time_raw', 'bold', 'meta'])
# {'sub': 41, 'bids_sub': 'p41cs', 'nwb_sub': 'CS41', 'nwb_path': '/Volumes/Extreme SSD/GT/PSYC8803/data/bmovie/nwb_files/000623/sub-CS41/sub-CS41_ses-P41CSR1_behavior+ecephys.nwb', 'fs_macro_raw': np.float64(1000.0), 'fs_micro_raw': np.float64(1000.0), 'fs_eye_raw': np.float64(499.9999999976126), 'movie_fps_nominal': 25.0, 'grid_source': 'lfp_raw', 'grid_dt': 0.000999999999990564, 'time_reference': 'movie_start_is_zero', 'lfp_baseline_seconds_pre_movie': 10.0, 'spikes_are_movie_referenced': True, 'lfp_is_movie_referenced_after_conversion': True, 'movieframe_time_is_frame_index': True, 'n_units': 7, 'fmri_error': None, 'max_nwb_samples': 2000000}
# (763964, 96) (763964, 2)
# band keys: ['theta', 'alpha', 'beta', 'gamma', 'high_gamma']
# (763964, 96) 763964

# %%
eye_data = data[41]["eye_gaze"]
print("movie_time shape:", data[41]["movieframe_time"].shape)
print("eye_gaze shape:", eye_data.shape)
print(eye_data[:5])
# Out:
# movie_time shape: (11971,)
# eye_gaze shape: (763964, 2)
# [[630.07562256 548.12335205]
#  [630.07562256 548.12335205]
#  [630.07562256 548.12335205]
#  [630.07562256 548.12335205]
#  [630.07562256 548.12335205]]

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from matplotlib import pyplot as plt

seg = slicer.slice_modalities_by_movie_time_sec(data[41], 0.0, 10.0)

X = seg["lfp_micro"]

X_std = StandardScaler().fit_transform(X)

pca = PCA(n_components=7)
X_pca = pca.fit_transform(X_std)

plt.figure(figsize=(8, 5))
plt.plot(np.cumsum(pca.explained_variance_ratio_), marker='o')
plt.axhline(
    y=0.95,
    color='r',
    linestyle='--',
    label='95% variance'
)

plt.text(
    x=0,
    y=0.95,
    s="95% variance",
    color='r',
    ha='left',
    va='bottom'
)
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('PCA Explained Variance')
# Out:
# Text(0.5, 1.0, 'PCA Explained Variance')

# %%
import matplotlib.pyplot as plt

for i in range(3):
    plt.plot(X_pca[:, i], label=f'PC{i+1}')

plt.legend()
plt.xlabel("time")
plt.ylabel("PC value")
plt.title("PCA Components Over Time")
plt.show()

plt.figure(figsize=(5, 5))
for i in range(3):
    j = (i + 1) % 3
    plt.plot(X_pca[:, i], X_pca[:, j],label=f'PC{i+1} vs PC{j+1}')
    

plt.legend(bbox_to_anchor=(1.05, 0), loc='lower left')
plt.xlabel("PC value")
plt.ylabel("PC value")
plt.title("PCA Component Trajectories")
plt.axis('equal')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

R = 5
T = X_pca.shape[0]
theta = np.linspace(0, 2*np.pi, T, endpoint=True)

plt.figure(figsize=(5, 5))

for i in range(3):
    j = (i + 1) % 3

    x = X_pca[:, i]
    y = X_pca[:, j]

    p95 = np.percentile(np.sqrt(x**2 + y**2), 95)
    s = (0.25 * R) / (p95 + 1e-9)

    cx = R * np.cos(theta)
    cy = R * np.sin(theta)

    X = cx + s * x
    Y = cy + s * y

    plt.plot(X, Y, label=f'PC{i+1} vs PC{j+1}')

    plt.scatter(X[0],  Y[0],  s=40, marker='o')
    plt.scatter(X[-1], Y[-1], s=40, marker='x')

tt = np.linspace(0, 2*np.pi, 400)
plt.plot(R*np.cos(tt), R*np.sin(tt), linewidth=1, alpha=0.3)

plt.legend(bbox_to_anchor=(1.05, 0), loc='lower left')
plt.axis('equal')
plt.xlabel("time-circle + scaled PCA-x")
plt.ylabel("time-circle + scaled PCA-y")
plt.title("Trajectory with Time Embedded on a Circle (R=20)")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def finite_diff(X, dt=1.0):
    """Centered finite difference for dX/dt (same length as X)."""
    dX = np.zeros_like(X)
    dX[1:-1] = (X[2:] - X[:-2]) / (2 * dt)
    dX[0]    = (X[1] - X[0]) / dt
    dX[-1]   = (X[-1] - X[-2]) / dt
    return dX

def fit_skew_M(X, dX):
    """
    Fit skew-symmetric M to minimize ||dX - X M^T||_F
    with constraint M^T = -M.
    """
    T, D = X.shape
    assert dX.shape == X.shape

    # Build linear system A m = b for upper-triangular free params of M
    # Parameterize M by entries m_ij for i<j, with:
    # M[i,j]=m_ij, M[j,i]=-m_ij, diag=0.
    pairs = [(i, j) for i in range(D) for j in range(i+1, D)]
    P = len(pairs)

    A = np.zeros((T * D, P), dtype=float)
    b = dX.reshape(-1)

    # For each time t and row k:
    # (X M^T)[t,k] = sum_l X[t,l] * M[k,l]
    # and M[k,l] expressed via m_ij.
    row = 0
    for t in range(T):
        x = X[t]
        for k in range(D):
            for p_idx, (i, j) in enumerate(pairs):
                val = 0.0
                # contribution from M[k,i] and M[k,j] if they exist
                # M[k,l] is:
                #  - if k==i and l==j: +m_ij
                #  - if k==j and l==i: -m_ij
                #  - if k==j and l==i handled similarly, etc.
                if k == i:
                    # term X[t, j] * M[i, j] = X_j * (+m_ij)
                    val += x[j]
                elif k == j:
                    # term X[t, i] * M[j, i] = X_i * (-m_ij)
                    val -= x[i]
                # also need terms where l==k and k==i/j? already covered above (since M[k,l])
                A[row, p_idx] = val
            row += 1

    # Solve least squares
    m_hat, *_ = np.linalg.lstsq(A, b, rcond=None)

    # Reconstruct M
    D = X.shape[1]
    M = np.zeros((D, D), dtype=float)
    for p_idx, (i, j) in enumerate(pairs):
        M[i, j] = m_hat[p_idx]
        M[j, i] = -m_hat[p_idx]
    return M

def jpca(X, dt=1.0, center=True):
    """
    X: (T, D) single trajectory (time-ordered).
    Returns:
      Xc: centered X used for fit
      M: skew-symmetric fitted dynamics
      W: (D,2) jPC plane basis
      Z: (T,2) projected trajectory in jPC plane
    """
    X_use = X.copy()
    if center:
        X_use = X_use - X_use.mean(axis=0, keepdims=True)

    dX = finite_diff(X_use, dt=dt)
    M = fit_skew_M(X_use, dX)

    # For skew-symmetric M, eigenvalues are ± iω. Take the pair with largest |ω|.
    evals, evecs = np.linalg.eig(M)
    omegas = np.abs(np.imag(evals))
    idx = np.argsort(omegas)[::-1]

    # pick the first eigenvector; its conjugate spans the same 2D plane
    v = evecs[:, idx[0]]
    W = np.column_stack([np.real(v), np.imag(v)])  # (D,2)

    # Orthonormalize W
    W, _ = np.linalg.qr(W)

    Z = X_use @ W
    return X_use, M, W, Z

# ====== X_pca jPCA ======
X = X_pca[:, :6]
dt = 1/30

Xc, M, W, Z = jpca(X, dt=dt, center=True)

# ====== jPC1 vs jPC2 ======
plt.figure(figsize=(7, 6))
plt.plot(Z[:, 0], Z[:, 1], lw=1)
plt.scatter(Z[0, 0], Z[0, 1], s=50, color='red', marker='o', label='start')
plt.scatter(Z[-1, 0], Z[-1, 1], s=50, color='green', marker='s', label='end')
plt.axhline(0, lw=1)
plt.axvline(0, lw=1)
plt.xlabel("jPC1")
plt.ylabel("jPC2")
plt.title("jPCA trajectory (projected onto jPC1-jPC2)")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # 4. Face Encoding Model
# ## 4.1 Feature Engineering

# %%
all_window_data = feature.build_all_subject_window_datasets(
    out=data,
    df_face_note=df_face_note,
    window_size_sec=0.5,          # 500 ms
    stride_sec=0.1,               # 100 ms stride
    start_time=0.0,
    end_time=478.800,
    remove_baseline_windows=True,
    do_baseline_norm=True,
    baseline_mode="zscore",
    baseline_start=-10.0,
    baseline_end=0.0,
    modality_keys=["firing_rate", "lfp_macro", "lfp_micro", "eye_gaze", "pupil"],
    use_only_valid_face_frames=True,
    valid_face_mode="front_or_face",
    require_all_modalities_nonempty=False,
    verbose=True,
)

all_window_data_filtered = {}

# filter valid window, face ratio, min_frame
for sub, sub_data in all_window_data.items():
    all_window_data_filtered[sub] = feature.filter_window_dataset(
        sub_data,
        valid_window_only=True,
        min_valid_face_ratio=0.25,
        min_face_frames=5,
        min_non_neutral=None,
        allowed_hard_labels=None,
        require_modalities_nonempty=["firing_rate"],
        verbose=True,
    )

concat_data = feature.concat_subject_window_data(
    all_window_data_filtered,
    subjects=None,
    modality_keys=["firing_rate", "lfp_macro", "lfp_micro", "eye_gaze", "pupil"],
    add_subject_column=True,
    reset_index=True,
    verbose=True,
)
# Out:
# [build] subject 41
#   -> n_windows = 4784, valid_windows = 4784
# [build] subject 42
#   -> n_windows = 4784, valid_windows = 4784
# [build] subject 43
#   -> n_windows = 4784, valid_windows = 4784
# [build] subject 44
#   -> n_windows = 4784, valid_windows = 4784
# [build] subject 45
# [failed] subject 45: ValueError('sub_dict missing baseline_time_key: time_grid')
# [filter_window_dataset] kept 3801 / 4784 windows
# [filter_window_dataset] kept 3801 / 4784 windows
# [filter_window_dataset] kept 3801 / 4784 windows
# [filter_window_dataset] kept 3801 / 4784 windows
# [concat] sub=41, n_windows=3801
# [concat] sub=42, n_windows=3801
# [concat] sub=43, n_windows=3801
# [concat] sub=44, n_windows=3801
# [concat_subject_window_data] total windows = 15204

# %%
print(concat_data["window_df"].columns)
# Out:
# Index(['sub', 'window_start', 'window_end', 'n_timepoints', 'valid_window',
#        'n_face_frames_total', 'emo_afraid', 'emo_angry', 'emo_happy',
#        'emo_neutral', 'emo_surprised', 'p_non_neutral', 'hard_label',
#        'valid_face_ratio', 'front_face_ratio', 'jacky_ratio', 'mean_n_faces'],
#       dtype='str')

# %%
pca_res = decompose.run_grouped_trajectory_pca_on_concat_data(concat_data, modality="lfp_micro", n_components=5, split_by_sub=True)

# decompose.plot_grouped_pca_across_sub(pca_res, pcx=1, pcy=2, alpha=0.3, equal_axis=True)
# decompose.plot_grouped_pca_across_sub(pca_res, pcx=2, pcy=3, alpha=0.3, equal_axis=True)
decompose.plot_pc_time_series_across_sub(pca_res)

decompose.run_decoding_on_pca_res(pca_res, mode="time_mean")
decompose.run_decoding_on_pca_res(pca_res, mode="stats")
# decompose.run_decoding_on_pca_res(pca_res, mode="channel_mean")
# Out:
# [lfp_micro] [sub=41] split by: emo
# [lfp_micro] [sub=41] neutral windows: 3301
# [lfp_micro] [sub=41] nonneutral windows: 500
# [lfp_micro] [sub=41] shared explained variance ratio: [0.27067676 0.20855851 0.12414037 0.0888615  0.07431705]
# [lfp_micro] [sub=42] split by: emo
# [lfp_micro] [sub=42] neutral windows: 3301
# [lfp_micro] [sub=42] nonneutral windows: 500
# [lfp_micro] [sub=42] shared explained variance ratio: [0.13281301 0.09780897 0.0687588  0.06585322 0.05338659]
# [lfp_micro] [sub=43] split by: emo
# [lfp_micro] [sub=43] neutral windows: 3301
# [lfp_micro] [sub=43] nonneutral windows: 500
# [lfp_micro] [sub=43] shared explained variance ratio: [0.25229865 0.14344566 0.133789   0.0805853  0.06714341]
# [lfp_micro] [sub=44] split by: emo
# [lfp_micro] [sub=44] neutral windows: 3301
# [lfp_micro] [sub=44] nonneutral windows: 500
# [lfp_micro] [sub=44] shared explained variance ratio: [0.21388491 0.13130503 0.08122411 0.07310022 0.06272841]
# dict_keys([np.int64(41), np.int64(42), np.int64(43), np.int64(44)])
# === Decoding results ===
# Groups: neutral vs nonneutral
# Mode: time_mean
# Total samples: 15204
# Total subjects: 4
#
# [Logistic Regression]
# Acc: 0.500 ± 0.006
# AUC: 0.480 ± 0.007
#
# [SVM]
# Acc: 0.868 ± 0.000
# AUC: 0.498 ± 0.013
# === Decoding results ===
# Groups: neutral vs nonneutral
# Mode: stats
# Total samples: 15204
# Total subjects: 4
#
# [Logistic Regression]
# Acc: 0.498 ± 0.009
# AUC: 0.539 ± 0.012
#
# [SVM]
# Acc: 0.868 ± 0.000
# AUC: 0.501 ± 0.010
# {'logreg': {'acc': array([0.50575469, 0.50279513, 0.50739888, 0.48635317, 0.48684211]),
#   'auc': array([0.54125899, 0.52813234, 0.55691121, 0.5437836 , 0.52352367])},
#  'svm': {'acc': array([0.86846432, 0.86846432, 0.86846432, 0.86846432, 0.86842105]),
#   'auc': array([0.48736463, 0.51810583, 0.50562192, 0.49698883, 0.49704545])},
#  'X': array([[-1.46627   ,  1.57416725,  1.30815969, ...,  0.94328585,
#           0.21399613, -0.58875672],
#         [-1.86462344,  1.57236473,  0.69106583, ..., -1.13288506,
#           0.04980684, -0.51589184],
#         [-1.40523024,  0.83831067,  0.54217626, ..., -0.76412057,
#           0.64692692, -0.43432513],
#         ...,
#         [ 0.65258483, -1.33567184, -0.32115161, ..., -0.53877484,
#          -0.4939798 ,  0.23146   ],
#         [ 0.46083411, -0.98315794, -0.58025873, ..., -0.03963227,
#           0.89050207, -0.09246899],
#         [-0.21026169, -0.06570661, -0.44473942, ...,  0.98028761,
#           1.31824886, -0.17064047]], shape=(15204, 25)),
#  'y': array([0, 0, 0, ..., 1, 1, 1], shape=(15204,)),
#  'sub_labels': array([np.int64(41), np.int64(41), np.int64(41), ..., np.int64(44),
#         np.int64(44), np.int64(44)], shape=(15204,), dtype=object),
#  'groups': ('neutral', 'nonneutral'),
#  'n_subjects': 4}

# %%
pca_res = decompose.run_grouped_trajectory_pca_on_concat_data(concat_data, spliter="jacky", eps=1.0, modality="lfp_micro", n_components=5, split_by_sub=True)

# decompose.plot_grouped_pca_across_sub(pca_res, pcx=1, pcy=2, alpha=0.3, equal_axis=True)
# decompose.plot_grouped_pca_across_sub(pca_res, pcx=2, pcy=3, alpha=0.3, equal_axis=True)
decompose.plot_pc_time_series_across_sub(pca_res)

decompose.run_decoding_on_pca_res(pca_res, mode="time_mean")
decompose.run_decoding_on_pca_res(pca_res, mode="stats")
decompose.run_decoding_on_pca_res(pca_res, mode="bandpower")
# decompose.run_decoding_on_pca_res(pca_res, mode="channel_mean")
# Out:
# 0.0 1.0
# [lfp_micro] [sub=41] split by: jacky
# [lfp_micro] [sub=41] no_jacky windows: 919
# [lfp_micro] [sub=41] jacky_present windows: 2882
# [lfp_micro] [sub=41] shared explained variance ratio: [0.27067676 0.20855851 0.12414037 0.0888615  0.07431705]
# 0.0 1.0
# [lfp_micro] [sub=42] split by: jacky
# [lfp_micro] [sub=42] no_jacky windows: 919
# [lfp_micro] [sub=42] jacky_present windows: 2882
# [lfp_micro] [sub=42] shared explained variance ratio: [0.13281301 0.09780897 0.0687588  0.06585322 0.05338659]
# 0.0 1.0
# [lfp_micro] [sub=43] split by: jacky
# [lfp_micro] [sub=43] no_jacky windows: 919
# [lfp_micro] [sub=43] jacky_present windows: 2882
# [lfp_micro] [sub=43] shared explained variance ratio: [0.25229865 0.14344566 0.133789   0.0805853  0.06714341]
# 0.0 1.0
# [lfp_micro] [sub=44] split by: jacky
# [lfp_micro] [sub=44] no_jacky windows: 919
# [lfp_micro] [sub=44] jacky_present windows: 2882
# [lfp_micro] [sub=44] shared explained variance ratio: [0.21388491 0.13130503 0.08122411 0.07310022 0.06272841]
# === Decoding results ===
# Groups: no_jacky vs jacky_present
# Mode: time_mean
# Total samples: 15204
# Total subjects: 4
#
# [Logistic Regression]
# Acc: 0.498 ± 0.007
# AUC: 0.487 ± 0.008
#
# [SVM]
# Acc: 0.758 ± 0.000
# AUC: 0.505 ± 0.008
# === Decoding results ===
# Groups: no_jacky vs jacky_present
# Mode: stats
# Total samples: 15204
# Total subjects: 4
#
# [Logistic Regression]
# Acc: 0.508 ± 0.009
# AUC: 0.546 ± 0.011
#
# [SVM]
# Acc: 0.758 ± 0.000
# AUC: 0.521 ± 0.011
# === Decoding results ===
# Groups: no_jacky vs jacky_present
# Mode: bandpower
# Total samples: 15204
# Total subjects: 4
#
# [Logistic Regression]
# Acc: 0.521 ± 0.024
# AUC: 0.540 ± 0.017
#
# [SVM]
# Acc: 0.758 ± 0.000
# AUC: 0.502 ± 0.026
# {'logreg': {'acc': array([0.5100296 , 0.51134495, 0.54653075, 0.48766853, 0.55098684]),
#   'auc': array([0.53605465, 0.55713637, 0.55575753, 0.51081296, 0.54155621])},
#  'svm': {'acc': array([0.75797435, 0.75830319, 0.75830319, 0.75830319, 0.75822368]),
#   'auc': array([0.46841283, 0.48849378, 0.51354054, 0.54512334, 0.49507932])},
#  'X': array([[0.        , 0.        , 0.        , ..., 0.        , 0.17353135,
#          0.06283165],
#         [0.        , 0.        , 0.        , ..., 0.        , 0.09648166,
#          0.04418948],
#         [0.        , 0.        , 0.        , ..., 0.        , 0.21702659,
#          0.0536935 ],
#         ...,
#         [0.        , 0.        , 0.        , ..., 0.        , 0.02715877,
#          0.05488342],
#         [0.        , 0.        , 0.        , ..., 0.        , 0.02930194,
#          0.0401438 ],
#         [0.        , 0.        , 0.        , ..., 0.        , 0.03476227,
#          0.04069357]], shape=(15204, 25)),
#  'y': array([0, 0, 0, ..., 1, 1, 1], shape=(15204,)),
#  'sub_labels': array([np.int64(41), np.int64(41), np.int64(41), ..., np.int64(44),
#         np.int64(44), np.int64(44)], shape=(15204,), dtype=object),
#  'groups': ('no_jacky', 'jacky_present'),
#  'n_subjects': 4}

# %%
pca_res = decompose.run_grouped_trajectory_pca_on_concat_data(concat_data, spliter="front_face", eps=1.0, modality="lfp_micro", n_components=5, split_by_sub=True)

# decompose.plot_grouped_pca_across_sub(pca_res, pcx=1, pcy=2, alpha=0.3, equal_axis=True)
# decompose.plot_grouped_pca_across_sub(pca_res, pcx=2, pcy=3, alpha=0.3, equal_axis=True)
decompose.plot_pc_time_series_across_sub(pca_res)

decompose.run_decoding_on_pca_res(pca_res, mode="time_mean")
decompose.run_decoding_on_pca_res(pca_res, mode="stats")
# decompose.run_decoding_on_pca_res(pca_res, mode="channel_mean")
# Out:
# [lfp_micro] [sub=41] split by: front_face
# [lfp_micro] [sub=41] no_front_face windows: 2779
# [lfp_micro] [sub=41] front_face_present windows: 1022
# [lfp_micro] [sub=41] shared explained variance ratio: [0.27067676 0.20855851 0.12414037 0.0888615  0.07431705]
# [lfp_micro] [sub=42] split by: front_face
# [lfp_micro] [sub=42] no_front_face windows: 2779
# [lfp_micro] [sub=42] front_face_present windows: 1022
# [lfp_micro] [sub=42] shared explained variance ratio: [0.13281301 0.09780897 0.0687588  0.06585322 0.05338659]
# [lfp_micro] [sub=43] split by: front_face
# [lfp_micro] [sub=43] no_front_face windows: 2779
# [lfp_micro] [sub=43] front_face_present windows: 1022
# [lfp_micro] [sub=43] shared explained variance ratio: [0.25229865 0.14344566 0.133789   0.0805853  0.06714341]
# [lfp_micro] [sub=44] split by: front_face
# [lfp_micro] [sub=44] no_front_face windows: 2779
# [lfp_micro] [sub=44] front_face_present windows: 1022
# [lfp_micro] [sub=44] shared explained variance ratio: [0.21388491 0.13130503 0.08122411 0.07310022 0.06272841]
# === Decoding results ===
# Groups: no_front_face vs front_face_present
# Mode: time_mean
# Total samples: 15204
# Total subjects: 4
#
# [Logistic Regression]
# Acc: 0.498 ± 0.006
# AUC: 0.492 ± 0.006
#
# [SVM]
# Acc: 0.731 ± 0.000
# AUC: 0.498 ± 0.009
# === Decoding results ===
# Groups: no_front_face vs front_face_present
# Mode: stats
# Total samples: 15204
# Total subjects: 4
#
# [Logistic Regression]
# Acc: 0.494 ± 0.014
# AUC: 0.504 ± 0.012
#
# [SVM]
# Acc: 0.731 ± 0.000
# AUC: 0.507 ± 0.008
# {'logreg': {'acc': array([0.49950674, 0.49358764, 0.50707004, 0.50378165, 0.46677632]),
#   'auc': array([0.49126476, 0.50451712, 0.5183946 , 0.51672556, 0.48967647])},
#  'svm': {'acc': array([0.73133838, 0.73100954, 0.73100954, 0.73100954, 0.73125   ]),
#   'auc': array([0.49326695, 0.50690162, 0.50794704, 0.51932508, 0.50971126])},
#  'X': array([[-1.46627   ,  1.57416725,  1.30815969, ...,  0.94328585,
#           0.21399613, -0.58875672],
#         [-1.86462344,  1.57236473,  0.69106583, ..., -1.13288506,
#           0.04980684, -0.51589184],
#         [-1.40523024,  0.83831067,  0.54217626, ..., -0.76412057,
#           0.64692692, -0.43432513],
#         ...,
#         [ 0.65258483, -1.33567184, -0.32115161, ..., -0.53877484,
#          -0.4939798 ,  0.23146   ],
#         [ 0.46083411, -0.98315794, -0.58025873, ..., -0.03963227,
#           0.89050207, -0.09246899],
#         [-0.21026169, -0.06570661, -0.44473942, ...,  0.98028761,
#           1.31824886, -0.17064047]], shape=(15204, 25)),
#  'y': array([0, 0, 0, ..., 1, 1, 1], shape=(15204,)),
#  'sub_labels': array([np.int64(41), np.int64(41), np.int64(41), ..., np.int64(44),
#         np.int64(44), np.int64(44)], shape=(15204,), dtype=object),
#  'groups': ('no_front_face', 'front_face_present'),
#  'n_subjects': 4}

# %% [markdown]
# ## 4.2 Modality Fusion
# ### 4.2.1 Feature Summary

# %%
subject_latent_res = new_fusion.build_subjectwise_modality_latents(
    concat_data,
    modality_keys=["firing_rate", "lfp_macro", "lfp_micro", "eye_gaze", "pupil"],
    feature_mode="bandpower",
    pca_dim=10,
    sub_col="sub",
    verbose=True,
)

y_dict = new_fusion.get_label_dict_from_concat_data(
    concat_data,
    y_col="emo_neutral",
    sub_col="sub",
)

stacked_latent = new_fusion.stack_subjectwise_latents(
    subject_latent_res,
    y_dict=y_dict,
    verbose=True,
)

syn_res = new_fusion.compute_pairwise_synergy_matrix_from_latents(
    stacked_latent,
    cv=5,
    verbose=True,
)

new_fusion.plot_synergy_matrix(syn_res)
# Out:
# [split] sub=41: n_windows=3801
# [split] sub=42: n_windows=3801
# [split] sub=43: n_windows=3801
# [split] sub=44: n_windows=3801
# [firing_rate] X.shape=(3801, 42), valid=3801/3801
# [lfp_macro] X.shape=(3801, 576), valid=3801/3801
# [lfp_micro] X.shape=(3801, 480), valid=3801/3801
# [eye_gaze] X.shape=(3801, 12), valid=3801/3801
# [pupil] X.shape=(3801, 6), valid=3801/3801
# [subject PCA] sub=41, mod=firing_rate, X_use.shape=(3801, 42), Z.shape=(3801, 10)
# [subject PCA] sub=41, mod=lfp_macro, X_use.shape=(3801, 576), Z.shape=(3801, 10)
# [subject PCA] sub=41, mod=lfp_micro, X_use.shape=(3801, 480), Z.shape=(3801, 10)
# [subject PCA] sub=41, mod=eye_gaze, X_use.shape=(3801, 12), Z.shape=(3801, 10)
# [subject PCA] sub=41, mod=pupil, X_use.shape=(3801, 6), Z.shape=(3801, 6)
# [firing_rate] X.shape=(3801, 300), valid=3801/3801
# [lfp_macro] X.shape=(3801, 576), valid=3801/3801
# [lfp_micro] X.shape=(3801, 384), valid=3801/3801
# [eye_gaze] X.shape=(3801, 12), valid=3801/3801
# [pupil] X.shape=(3801, 6), valid=3801/3801
# [subject PCA] sub=42, mod=firing_rate, X_use.shape=(3801, 300), Z.shape=(3801, 10)
# [subject PCA] sub=42, mod=lfp_macro, X_use.shape=(3801, 576), Z.shape=(3801, 10)
# [subject PCA] sub=42, mod=lfp_micro, X_use.shape=(3801, 384), Z.shape=(3801, 10)
# [subject PCA] sub=42, mod=eye_gaze, X_use.shape=(3801, 12), Z.shape=(3801, 10)
# [subject PCA] sub=42, mod=pupil, X_use.shape=(3801, 6), Z.shape=(3801, 6)
# [firing_rate] X.shape=(3801, 192), valid=3801/3801
# [lfp_macro] X.shape=(3801, 576), valid=3801/3801
# [lfp_micro] X.shape=(3801, 480), valid=3801/3801
# [eye_gaze] X.shape=(3801, 12), valid=3801/3801
# [pupil] X.shape=(3801, 6), valid=3801/3801
# [subject PCA] sub=43, mod=firing_rate, X_use.shape=(3801, 192), Z.shape=(3801, 10)
# [subject PCA] sub=43, mod=lfp_macro, X_use.shape=(3801, 576), Z.shape=(3801, 10)
# [subject PCA] sub=43, mod=lfp_micro, X_use.shape=(3801, 480), Z.shape=(3801, 10)
# [subject PCA] sub=43, mod=eye_gaze, X_use.shape=(3801, 12), Z.shape=(3801, 10)
# [subject PCA] sub=43, mod=pupil, X_use.shape=(3801, 6), Z.shape=(3801, 6)
# [firing_rate] X.shape=(3801, 294), valid=3801/3801
# [lfp_macro] X.shape=(3801, 576), valid=3801/3801
# [lfp_micro] X.shape=(3801, 384), valid=3801/3801
# [eye_gaze] X.shape=(3801, 12), valid=3801/3801
# [pupil] X.shape=(3801, 6), valid=3801/3801
# [subject PCA] sub=44, mod=firing_rate, X_use.shape=(3801, 294), Z.shape=(3801, 10)
# [subject PCA] sub=44, mod=lfp_macro, X_use.shape=(3801, 576), Z.shape=(3801, 10)
# [subject PCA] sub=44, mod=lfp_micro, X_use.shape=(3801, 384), Z.shape=(3801, 10)
# [subject PCA] sub=44, mod=eye_gaze, X_use.shape=(3801, 12), Z.shape=(3801, 10)
# [subject PCA] sub=44, mod=pupil, X_use.shape=(3801, 6), Z.shape=(3801, 6)
# [stack latent] mod=eye_gaze, shape=(15204, 10), K_common=10
# [stack latent] mod=firing_rate, shape=(15204, 10), K_common=10
# [stack latent] mod=lfp_macro, shape=(15204, 10), K_common=10
# [stack latent] mod=lfp_micro, shape=(15204, 10), K_common=10
# [stack latent] mod=pupil, shape=(15204, 6), K_common=6
# [single latent] eye_gaze: AUC=0.5523 ± 0.0138
# [single latent] firing_rate: AUC=0.5877 ± 0.0093
# [single latent] lfp_macro: AUC=0.6111 ± 0.0201
# [single latent] lfp_micro: AUC=0.5801 ± 0.0170
# [single latent] pupil: AUC=0.5033 ± 0.0146
# [pair latent] eye_gaze+firing_rate: AUC=0.5975 ± 0.0094, synergy=0.0098
# [pair latent] eye_gaze+lfp_macro: AUC=0.6143 ± 0.0204, synergy=0.0031
# [pair latent] eye_gaze+lfp_micro: AUC=0.5934 ± 0.0191, synergy=0.0134
# [pair latent] eye_gaze+pupil: AUC=0.5518 ± 0.0090, synergy=-0.0005
# [pair latent] firing_rate+lfp_macro: AUC=0.6408 ± 0.0129, synergy=0.0297
# [pair latent] firing_rate+lfp_micro: AUC=0.6136 ± 0.0102, synergy=0.0259
# [pair latent] firing_rate+pupil: AUC=0.5874 ± 0.0082, synergy=-0.0003
# [pair latent] lfp_macro+lfp_micro: AUC=0.6279 ± 0.0190, synergy=0.0168
# [pair latent] lfp_macro+pupil: AUC=0.6110 ± 0.0203, synergy=-0.0001
# [pair latent] lfp_micro+pupil: AUC=0.5794 ± 0.0175, synergy=-0.0007

# %% [markdown]
# ## AUC Sanity Checking

# %%
import numpy as np
import pandas as pd
from itertools import combinations

from sklearn.pipeline import make_pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import StratifiedKFold, cross_val_score


def _cv_auc(X, y, cv=5, random_state=42):
    X = np.asarray(X, dtype=float)
    y = np.asarray(y)

    model = make_pipeline(
        SimpleImputer(strategy="mean"),
        StandardScaler(),
        LogisticRegression(max_iter=2000, class_weight="balanced")
    )

    skf = StratifiedKFold(n_splits=cv, shuffle=True, random_state=random_state)
    aucs = cross_val_score(model, X, y, cv=skf, scoring="roc_auc")
    return float(np.mean(aucs)), float(np.std(aucs))


def sanity_check_single_modalities_multisub(
    feat_dict_by_sub,
    valid_mask_dict_by_sub,
    y_dict,
    cv=5,
    n_perm=20,
    random_state=42,
    min_windows=10,
    return_per_subject=True,
    verbose=True,
):
    """
    Parameters
    ----------
    feat_dict_by_sub : dict
        {
            sub1: {mod1: [N_sub, F], mod2: ...},
            sub2: ...
        }

    valid_mask_dict_by_sub : dict
        {
            sub1: {mod1: [N_sub] bool, mod2: ...},
            sub2: ...
        }

    y_dict : dict
        {
            sub1: [N_sub],
            sub2: [N_sub],
            ...
        }

    Returns
    -------
    summary_df : DataFrame
        one row per modality, aggregated across subjects

    per_sub_df : DataFrame
        one row per subject x modality
    """
    rng = np.random.default_rng(random_state)

    all_mods = sorted(list(set(
        m for sub in feat_dict_by_sub
        for m in feat_dict_by_sub[sub].keys()
    )))

    rows = []

    for sub in sorted(feat_dict_by_sub.keys()):
        if sub not in valid_mask_dict_by_sub:
            continue
        if sub not in y_dict:
            continue

        y = np.asarray(y_dict[sub])

        for mod in all_mods:
            if mod not in feat_dict_by_sub[sub]:
                continue
            if mod not in valid_mask_dict_by_sub[sub]:
                continue

            X = np.asarray(feat_dict_by_sub[sub][mod], dtype=float)
            mask = np.asarray(valid_mask_dict_by_sub[sub][mod], dtype=bool)

            if len(mask) != len(y):
                raise ValueError(
                    f"sub={sub}, mod={mod}: len(mask)={len(mask)} != len(y)={len(y)}"
                )
            if X.shape[0] != len(y):
                raise ValueError(
                    f"sub={sub}, mod={mod}: X.shape[0]={X.shape[0]} != len(y)={len(y)}"
                )

            mask = mask & np.isfinite(y)
            X_use = X[mask]
            y_use = y[mask]

            n_windows = int(mask.sum())
            n_classes = len(np.unique(y_use))

            if n_windows < max(cv, min_windows):
                if verbose:
                    print(f"[skip] sub={sub}, mod={mod}: too few windows ({n_windows})")
                continue

            if n_classes < 2:
                if verbose:
                    print(f"[skip] sub={sub}, mod={mod}: only one class")
                continue

            try:
                auc_mean, auc_std = _cv_auc(X_use, y_use, cv=cv, random_state=random_state)
            except Exception as e:
                if verbose:
                    print(f"[skip] sub={sub}, mod={mod}: CV failed ({e})")
                continue

            perm_aucs = []
            for _ in range(n_perm):
                y_perm = rng.permutation(y_use)
                try:
                    a, _ = _cv_auc(X_use, y_perm, cv=cv, random_state=random_state)
                    perm_aucs.append(a)
                except Exception:
                    pass

            perm_auc_mean = np.mean(perm_aucs) if len(perm_aucs) > 0 else np.nan
            perm_auc_std = np.std(perm_aucs) if len(perm_aucs) > 0 else np.nan

            rows.append({
                "sub": sub,
                "modality": mod,
                "n_windows": n_windows,
                "n_features": int(X_use.shape[1]),
                "auc_mean": auc_mean,
                "auc_std": auc_std,
                "perm_auc_mean": perm_auc_mean,
                "perm_auc_std": perm_auc_std,
                "delta_over_perm": auc_mean - perm_auc_mean if np.isfinite(perm_auc_mean) else np.nan,
            })

            if verbose:
                print(
                    f"[sub={sub}][{mod}] "
                    f"AUC={auc_mean:.4f}±{auc_std:.4f}, "
                    f"perm={perm_auc_mean:.4f}±{perm_auc_std:.4f}, "
                    f"delta={auc_mean - perm_auc_mean:.4f}"
                )

    per_sub_df = pd.DataFrame(rows)

    if len(per_sub_df) == 0:
        empty_cols = [
            "modality", "n_subjects", "mean_n_windows", "mean_n_features",
            "auc_mean_across_sub", "auc_std_across_sub",
            "perm_auc_mean_across_sub", "perm_auc_std_across_sub",
            "delta_over_perm_across_sub"
        ]
        summary_df = pd.DataFrame(columns=empty_cols)
        return (summary_df, per_sub_df) if return_per_subject else summary_df

    summary_df = (
        per_sub_df
        .groupby("modality", observed=True)
        .agg(
            n_subjects=("sub", "nunique"),
            mean_n_windows=("n_windows", "mean"),
            mean_n_features=("n_features", "mean"),
            auc_mean_across_sub=("auc_mean", "mean"),
            auc_std_across_sub=("auc_mean", "std"),
            perm_auc_mean_across_sub=("perm_auc_mean", "mean"),
            perm_auc_std_across_sub=("perm_auc_mean", "std"),
            delta_over_perm_across_sub=("delta_over_perm", "mean"),
        )
        .reset_index()
        .sort_values("auc_mean_across_sub", ascending=False)
        .reset_index(drop=True)
    )

    return (summary_df, per_sub_df) if return_per_subject else summary_df

def sanity_check_pairwise_synergy_multisub(
    feat_dict_by_sub,
    valid_mask_dict_by_sub,
    y_dict,
    cv=5,
    n_perm=20,
    random_state=42,
    min_windows=10,
    return_per_subject=True,
    verbose=True,
):
    """
    Multi-subject pairwise synergy check.

    Parameters
    ----------
    feat_dict_by_sub : dict
        {
            sub1: {mod1: [N_sub, F], mod2: ...},
            sub2: ...
        }

    valid_mask_dict_by_sub : dict
        {
            sub1: {mod1: [N_sub] bool, mod2: ...},
            sub2: ...
        }

    y_dict : dict
        {
            sub1: [N_sub],
            sub2: [N_sub],
            ...
        }

    Returns
    -------
    summary_df : DataFrame
        aggregated over subjects, one row per modality pair

    per_sub_df : DataFrame
        one row per subject x modality pair
    """
    rng = np.random.default_rng(random_state)

    all_mods = sorted(list(set(
        m for sub in feat_dict_by_sub
        for m in feat_dict_by_sub[sub].keys()
    )))

    rows = []

    for sub in sorted(feat_dict_by_sub.keys()):
        if sub not in valid_mask_dict_by_sub:
            continue
        if sub not in y_dict:
            continue

        feat_dict = feat_dict_by_sub[sub]
        valid_mask_dict = valid_mask_dict_by_sub[sub]
        y = np.asarray(y_dict[sub])

        # single-modality AUC
        single_auc = {}

        for mod in all_mods:
            if mod not in feat_dict or mod not in valid_mask_dict:
                single_auc[mod] = np.nan
                continue

            X = np.asarray(feat_dict[mod], dtype=float)
            mask = np.asarray(valid_mask_dict[mod], dtype=bool)

            if len(mask) != len(y):
                raise ValueError(
                    f"sub={sub}, mod={mod}: len(mask)={len(mask)} != len(y)={len(y)}"
                )
            if X.shape[0] != len(y):
                raise ValueError(
                    f"sub={sub}, mod={mod}: X.shape[0]={X.shape[0]} != len(y)={len(y)}"
                )

            mask = mask & np.isfinite(y)
            X_use = X[mask]
            y_use = y[mask]

            if int(mask.sum()) < max(cv, min_windows) or len(np.unique(y_use)) < 2:
                single_auc[mod] = np.nan
                continue

            try:
                single_auc[mod], _ = _cv_auc(X_use, y_use, cv=cv, random_state=random_state)
            except Exception:
                single_auc[mod] = np.nan

        # pairwise
        mods_sub = [m for m in all_mods if m in feat_dict and m in valid_mask_dict]

        for m1, m2 in combinations(mods_sub, 2):
            mask = (
                np.asarray(valid_mask_dict[m1], dtype=bool)
                & np.asarray(valid_mask_dict[m2], dtype=bool)
                & np.isfinite(y)
            )

            n_windows = int(mask.sum())
            if n_windows < max(cv, min_windows):
                if verbose:
                    print(f"[skip] sub={sub}, {m1}+{m2}: too few windows ({n_windows})")
                continue

            y_use = y[mask]
            if len(np.unique(y_use)) < 2:
                if verbose:
                    print(f"[skip] sub={sub}, {m1}+{m2}: only one class")
                continue

            X1 = np.asarray(feat_dict[m1], dtype=float)[mask]
            X2 = np.asarray(feat_dict[m2], dtype=float)[mask]
            X_joint = np.concatenate([X1, X2], axis=1)

            try:
                joint_auc, joint_std = _cv_auc(X_joint, y_use, cv=cv, random_state=random_state)
            except Exception as e:
                if verbose:
                    print(f"[skip] sub={sub}, {m1}+{m2}: CV failed ({e})")
                continue

            best_single = np.nanmax([single_auc.get(m1, np.nan), single_auc.get(m2, np.nan)])
            synergy = joint_auc - best_single if np.isfinite(best_single) else np.nan

            perm_joint_aucs = []
            for _ in range(n_perm):
                y_perm = rng.permutation(y_use)
                try:
                    a, _ = _cv_auc(X_joint, y_perm, cv=cv, random_state=random_state)
                    perm_joint_aucs.append(a)
                except Exception:
                    pass

            perm_joint_mean = np.mean(perm_joint_aucs) if len(perm_joint_aucs) > 0 else np.nan
            perm_joint_std = np.std(perm_joint_aucs) if len(perm_joint_aucs) > 0 else np.nan

            rows.append({
                "sub": sub,
                "mod1": m1,
                "mod2": m2,
                "n_windows": n_windows,
                "n_features_joint": int(X_joint.shape[1]),
                "joint_auc": joint_auc,
                "joint_std": joint_std,
                "best_single_auc": best_single,
                "synergy": synergy,
                "perm_joint_auc_mean": perm_joint_mean,
                "perm_joint_auc_std": perm_joint_std,
                "synergy_vs_perm_joint": joint_auc - perm_joint_mean if np.isfinite(perm_joint_mean) else np.nan,
            })

            if verbose:
                print(
                    f"[sub={sub}][{m1}+{m2}] "
                    f"joint={joint_auc:.4f}, "
                    f"best_single={best_single:.4f}, "
                    f"synergy={synergy:.4f}, "
                    f"vs_perm={joint_auc - perm_joint_mean:.4f}"
                )

    per_sub_df = pd.DataFrame(rows)

    if len(per_sub_df) == 0:
        empty_cols = [
            "mod1", "mod2", "pair", "n_subjects", "mean_n_windows",
            "joint_auc_across_sub", "joint_auc_std_across_sub",
            "best_single_auc_across_sub", "synergy_across_sub",
            "perm_joint_auc_mean_across_sub", "synergy_vs_perm_joint_across_sub"
        ]
        summary_df = pd.DataFrame(columns=empty_cols)
        return (summary_df, per_sub_df) if return_per_subject else summary_df

    per_sub_df["pair"] = per_sub_df["mod1"].astype(str) + " + " + per_sub_df["mod2"].astype(str)

    summary_df = (
        per_sub_df
        .groupby(["mod1", "mod2", "pair"], observed=True)
        .agg(
            n_subjects=("sub", "nunique"),
            mean_n_windows=("n_windows", "mean"),
            joint_auc_across_sub=("joint_auc", "mean"),
            joint_auc_std_across_sub=("joint_auc", "std"),
            best_single_auc_across_sub=("best_single_auc", "mean"),
            synergy_across_sub=("synergy", "mean"),
            synergy_std_across_sub=("synergy", "std"),
            perm_joint_auc_mean_across_sub=("perm_joint_auc_mean", "mean"),
            synergy_vs_perm_joint_across_sub=("synergy_vs_perm_joint", "mean"),
        )
        .reset_index()
        .sort_values("synergy_across_sub", ascending=False)
        .reset_index(drop=True)
    )

    return (summary_df, per_sub_df) if return_per_subject else summary_df

def extract_feat_inputs_from_subject_latent_res(subject_latent_res, use_latent=False):
    """
    use_latent=False -> 用 feat_dict
    use_latent=True  -> 用 latent_dict
    """
    feat_dict_by_sub = {}
    valid_mask_dict_by_sub = {}

    for sub, res in subject_latent_res.items():
        feat_dict_by_sub[sub] = res["latent_dict"] if use_latent else res["feat_dict"]
        valid_mask_dict_by_sub[sub] = res["valid_mask_dict"]

    return feat_dict_by_sub, valid_mask_dict_by_sub

# %%
y_dict = new_fusion.get_label_dict_from_concat_data(
    concat_data,
    y_col="emo_neutral",
    sub_col="sub",
)

feat_dict_by_sub, valid_mask_dict_by_sub = extract_feat_inputs_from_subject_latent_res(
    subject_latent_res,
    use_latent=False,
)

single_summary_df, single_per_sub_df = sanity_check_single_modalities_multisub(
    feat_dict_by_sub=feat_dict_by_sub,
    valid_mask_dict_by_sub=valid_mask_dict_by_sub,
    y_dict=y_dict,
    cv=5,
    n_perm=20,
    random_state=42,
    verbose=True,
)
display(single_summary_df)

pair_summary_df, pair_per_sub_df = sanity_check_pairwise_synergy_multisub(
    feat_dict_by_sub=feat_dict_by_sub,
    valid_mask_dict_by_sub=valid_mask_dict_by_sub,
    y_dict=y_dict,
    cv=5,
    n_perm=20,
    random_state=42,
    verbose=True,
)

display(pair_summary_df)
# Out:
# [sub=41][eye_gaze] AUC=0.6579±0.0368, perm=0.4990±0.0240, delta=0.1588
# [sub=41][firing_rate] AUC=0.5910±0.0266, perm=0.4976±0.0204, delta=0.0935
# [sub=41][lfp_macro] AUC=0.8844±0.0088, perm=0.4954±0.0197, delta=0.3890
# [sub=41][lfp_micro] AUC=0.9080±0.0067, perm=0.4976±0.0200, delta=0.4104
# [sub=41][pupil] AUC=0.5393±0.0364, perm=0.5042±0.0214, delta=0.0351
# [sub=42][eye_gaze] AUC=0.6639±0.0318, perm=0.5057±0.0182, delta=0.1582
# [sub=42][firing_rate] AUC=0.7675±0.0183, perm=0.4943±0.0262, delta=0.2731
# [sub=42][lfp_macro] AUC=0.8338±0.0152, perm=0.4996±0.0175, delta=0.3342
# [sub=42][lfp_micro] AUC=0.9425±0.0047, perm=0.4960±0.0178, delta=0.4465
# [sub=42][pupil] AUC=0.5441±0.0166, perm=0.4998±0.0182, delta=0.0442
# [sub=43][eye_gaze] AUC=0.6923±0.0131, perm=0.5012±0.0220, delta=0.1910
# [sub=43][firing_rate] AUC=0.8221±0.0328, perm=0.4964±0.0201, delta=0.3257
# [sub=43][lfp_macro] AUC=0.9186±0.0081, perm=0.5000±0.0226, delta=0.4186
# [sub=43][lfp_micro] AUC=0.8627±0.0084, perm=0.5016±0.0165, delta=0.3611
# [sub=43][pupil] AUC=0.5874±0.0199, perm=0.5009±0.0169, delta=0.0865
# [sub=44][eye_gaze] AUC=0.6164±0.0163, perm=0.4966±0.0240, delta=0.1198
# [sub=44][firing_rate] AUC=0.8157±0.0278, perm=0.4975±0.0208, delta=0.3181
# [sub=44][lfp_macro] AUC=0.8864±0.0184, perm=0.4914±0.0202, delta=0.3950
# [sub=44][lfp_micro] AUC=0.8388±0.0168, perm=0.4981±0.0211, delta=0.3407
# [sub=44][pupil] AUC=0.5021±0.0122, perm=0.5005±0.0231, delta=0.0016
#       modality  n_subjects  mean_n_windows  mean_n_features  \
# 0    lfp_micro           4          3801.0            360.0
# 1    lfp_macro           4          3801.0            480.0
# 2  firing_rate           4          3801.0            172.5
# 3     eye_gaze           4          3801.0             10.0
# 4        pupil           4          3801.0              5.0
#
#    auc_mean_across_sub  auc_std_across_sub  perm_auc_mean_across_sub  \
# 0             0.888023            0.046293                  0.498345
# 1             0.880793            0.035008                  0.496591
# 2             0.749057            0.108142                  0.496464
# 3             0.657584            0.031307                  0.500622
# 4             0.543218            0.034949                  0.501354
#
#    perm_auc_std_across_sub  delta_over_perm_across_sub
# 0                 0.002370                    0.389678
# 1                 0.004048                    0.384202
# 2                 0.001514                    0.252593
# 3                 0.003876                    0.156961
# 4                 0.001934                    0.041865
# [sub=41][eye_gaze+firing_rate] joint=0.6712, best_single=0.6579, synergy=0.0134, vs_perm=0.1722
# [sub=41][eye_gaze+lfp_macro] joint=0.8964, best_single=0.8844, synergy=0.0119, vs_perm=0.3946
# [sub=41][eye_gaze+lfp_micro] joint=0.9222, best_single=0.9080, synergy=0.0142, vs_perm=0.4210
# [sub=41][eye_gaze+pupil] joint=0.6617, best_single=0.6579, synergy=0.0039, vs_perm=0.1593
# [sub=41][firing_rate+lfp_macro] joint=0.8950, best_single=0.8844, synergy=0.0106, vs_perm=0.3926
# [sub=41][firing_rate+lfp_micro] joint=0.9115, best_single=0.9080, synergy=0.0035, vs_perm=0.4085
# [sub=41][firing_rate+pupil] joint=0.5927, best_single=0.5910, synergy=0.0016, vs_perm=0.0924
# [sub=41][lfp_macro+lfp_micro] joint=0.9573, best_single=0.9080, synergy=0.0493, vs_perm=0.4491
# [sub=41][lfp_macro+pupil] joint=0.8882, best_single=0.8844, synergy=0.0038, vs_perm=0.3907
# [sub=41][lfp_micro+pupil] joint=0.9109, best_single=0.9080, synergy=0.0029, vs_perm=0.4078
# [sub=42][eye_gaze+firing_rate] joint=0.8072, best_single=0.7675, synergy=0.0397, vs_perm=0.3097
# [sub=42][eye_gaze+lfp_macro] joint=0.8581, best_single=0.8338, synergy=0.0243, vs_perm=0.3612
# [sub=42][eye_gaze+lfp_micro] joint=0.9478, best_single=0.9425, synergy=0.0053, vs_perm=0.4573
# [sub=42][eye_gaze+pupil] joint=0.6749, best_single=0.6639, synergy=0.0111, vs_perm=0.1725
# [sub=42][firing_rate+lfp_macro] joint=0.8910, best_single=0.8338, synergy=0.0571, vs_perm=0.3936
# [sub=42][firing_rate+lfp_micro] joint=0.9569, best_single=0.9425, synergy=0.0144, vs_perm=0.4517
# [sub=42][firing_rate+pupil] joint=0.7722, best_single=0.7675, synergy=0.0048, vs_perm=0.2709
# [sub=42][lfp_macro+lfp_micro] joint=0.9639, best_single=0.9425, synergy=0.0214, vs_perm=0.4696
# [sub=42][lfp_macro+pupil] joint=0.8358, best_single=0.8338, synergy=0.0019, vs_perm=0.3311
# [sub=42][lfp_micro+pupil] joint=0.9474, best_single=0.9425, synergy=0.0049, vs_perm=0.4495
# [sub=43][eye_gaze+firing_rate] joint=0.8387, best_single=0.8221, synergy=0.0166, vs_perm=0.3384
# [sub=43][eye_gaze+lfp_macro] joint=0.9266, best_single=0.9186, synergy=0.0080, vs_perm=0.4232
# [sub=43][eye_gaze+lfp_micro] joint=0.8734, best_single=0.8627, synergy=0.0107, vs_perm=0.3765
# [sub=43][eye_gaze+pupil] joint=0.7528, best_single=0.6923, synergy=0.0605, vs_perm=0.2593
# [sub=43][firing_rate+lfp_macro] joint=0.9462, best_single=0.9186, synergy=0.0276, vs_perm=0.4481
# [sub=43][firing_rate+lfp_micro] joint=0.9211, best_single=0.8627, synergy=0.0583, vs_perm=0.4161
# [sub=43][firing_rate+pupil] joint=0.8218, best_single=0.8221, synergy=-0.0003, vs_perm=0.3281
# [sub=43][lfp_macro+lfp_micro] joint=0.9490, best_single=0.9186, synergy=0.0304, vs_perm=0.4476
# [sub=43][lfp_macro+pupil] joint=0.9207, best_single=0.9186, synergy=0.0021, vs_perm=0.4256
# [sub=43][lfp_micro+pupil] joint=0.8700, best_single=0.8627, synergy=0.0072, vs_perm=0.3750
# [sub=44][eye_gaze+firing_rate] joint=0.8216, best_single=0.8157, synergy=0.0059, vs_perm=0.3217
# [sub=44][eye_gaze+lfp_macro] joint=0.8921, best_single=0.8864, synergy=0.0058, vs_perm=0.3866
# [sub=44][eye_gaze+lfp_micro] joint=0.8437, best_single=0.8388, synergy=0.0048, vs_perm=0.3481
# [sub=44][eye_gaze+pupil] joint=0.6217, best_single=0.6164, synergy=0.0054, vs_perm=0.1176
# [sub=44][firing_rate+lfp_macro] joint=0.9515, best_single=0.8864, synergy=0.0652, vs_perm=0.4536
# [sub=44][firing_rate+lfp_micro] joint=0.8962, best_single=0.8388, synergy=0.0573, vs_perm=0.3924
# [sub=44][firing_rate+pupil] joint=0.8163, best_single=0.8157, synergy=0.0006, vs_perm=0.3087
# [sub=44][lfp_macro+lfp_micro] joint=0.9325, best_single=0.8864, synergy=0.0461, vs_perm=0.4339
# [sub=44][lfp_macro+pupil] joint=0.8852, best_single=0.8864, synergy=-0.0011, vs_perm=0.3855
# [sub=44][lfp_micro+pupil] joint=0.8389, best_single=0.8388, synergy=0.0001, vs_perm=0.3395
#           mod1         mod2                     pair  n_subjects  \
# 0  firing_rate    lfp_macro  firing_rate + lfp_macro           4
# 1    lfp_macro    lfp_micro    lfp_macro + lfp_micro           4
# 2  firing_rate    lfp_micro  firing_rate + lfp_micro           4
# 3     eye_gaze        pupil         eye_gaze + pupil           4
# 4     eye_gaze  firing_rate   eye_gaze + firing_rate           4
# 5     eye_gaze    lfp_macro     eye_gaze + lfp_macro           4
# 6     eye_gaze    lfp_micro     eye_gaze + lfp_micro           4
# 7    lfp_micro        pupil        lfp_micro + pupil           4
# 8  firing_rate        pupil      firing_rate + pupil           4
# 9    lfp_macro        pupil        lfp_macro + pupil           4
#
#    mean_n_windows  joint_auc_across_sub  joint_auc_std_across_sub  \
# 0          3801.0              0.920909                  0.032375
# 1          3801.0              0.950666                  0.013563
# 2          3801.0              0.921412                  0.025795
# 3          3801.0              0.677789                  0.054859
# 4          3801.0              0.784662                  0.076715
# 5          3801.0              0.893297                  0.028030
# 6          3801.0              0.896793                  0.046980
# 7          3801.0              0.891810                  0.047362
# 8          3801.0              0.750756                  0.107702
# 9          3801.0              0.882486                  0.035042
#
#    best_single_auc_across_sub  synergy_across_sub  synergy_std_across_sub  \
# 0                    0.880793            0.040117                0.025477
# 1                    0.913862            0.036804                0.013187
# 2                    0.888023            0.033389                0.028566
# 3                    0.657584            0.020205                0.027047
# 4                    0.765769            0.018893                0.014607
# 5                    0.880793            0.012504                0.008260
# 6                    0.888023            0.008771                0.004518
# 7                    0.888023            0.003787                0.003020
# 8                    0.749057            0.001699                0.002203
# 9                    0.880793            0.001694                0.002056
#
#    perm_joint_auc_mean_across_sub  synergy_vs_perm_joint_across_sub
# 0                        0.498949                          0.421960
# 1                        0.500608                          0.450058
# 2                        0.504207                          0.417205
# 3                        0.500626                          0.177163
# 4                        0.499149                          0.285513
# 5                        0.501889                          0.391408
# 6                        0.496061                          0.400732
# 7                        0.498873                          0.392937
# 8                        0.500746                          0.250010
# 9                        0.499258                          0.383228

# %% [markdown]
# ## CCA

# %%
cca_res = new_fusion.compute_pairwise_cca_subjectwise(
    subject_latent_res,
    modality_keys=["firing_rate", "lfp_macro", "lfp_micro", "eye_gaze", "pupil"],
    n_components=3,
    min_windows=20,
    verbose=True,
)

new_fusion.plot_cca_corr_heatmap_from_matrix(
    cca_res,
    modality_keys=["firing_rate", "lfp_macro", "lfp_micro", "eye_gaze", "pupil"],
    mode="first",
    title="Subject-wise pooled CCA matrix",
)

# new_fusion.plot_cca_pair_scatter(
#     cca_res,
#     "firing_rate",
#     "eye_gaze",
#     comp=1,
# )
# Out:
# [subject CCA] sub=41, firing_rate vs lfp_macro: 0.156, 0.140, 0.129
# [subject CCA] sub=42, firing_rate vs lfp_macro: 0.283, 0.223, 0.182
# [subject CCA] sub=43, firing_rate vs lfp_macro: 0.435, 0.248, 0.186
# [subject CCA] sub=44, firing_rate vs lfp_macro: 0.390, 0.219, 0.179
# [subject CCA] sub=41, firing_rate vs lfp_micro: 0.128, 0.101, 0.095
# [subject CCA] sub=42, firing_rate vs lfp_micro: 0.328, 0.251, 0.158
# [subject CCA] sub=43, firing_rate vs lfp_micro: 0.180, 0.157, 0.119
# [subject CCA] sub=44, firing_rate vs lfp_micro: 0.401, 0.226, 0.143
# [subject CCA] sub=41, firing_rate vs eye_gaze: 0.085, 0.071, 0.048
# [subject CCA] sub=42, firing_rate vs eye_gaze: 0.148, 0.081, 0.062
# [subject CCA] sub=43, firing_rate vs eye_gaze: 0.105, 0.073, 0.070
# [subject CCA] sub=44, firing_rate vs eye_gaze: 0.129, 0.112, 0.055
# [subject CCA] sub=41, firing_rate vs pupil: 0.073, 0.053, 0.045
# [subject CCA] sub=42, firing_rate vs pupil: 0.159, 0.058, 0.041
# [subject CCA] sub=43, firing_rate vs pupil: 0.069, 0.058, 0.040
# [subject CCA] sub=44, firing_rate vs pupil: 0.073, 0.049, 0.016
# [subject CCA] sub=41, lfp_macro vs lfp_micro: 0.315, 0.216, 0.146
# [subject CCA] sub=42, lfp_macro vs lfp_micro: 0.607, 0.419, 0.324
# [subject CCA] sub=43, lfp_macro vs lfp_micro: 0.618, 0.493, 0.344
# [subject CCA] sub=44, lfp_macro vs lfp_micro: 0.447, 0.300, 0.256
# [subject CCA] sub=41, lfp_macro vs eye_gaze: 0.106, 0.068, 0.057
# [subject CCA] sub=42, lfp_macro vs eye_gaze: 0.158, 0.070, 0.040
# [subject CCA] sub=43, lfp_macro vs eye_gaze: 0.213, 0.124, 0.084
# [subject CCA] sub=44, lfp_macro vs eye_gaze: 0.197, 0.114, 0.071
# [subject CCA] sub=41, lfp_macro vs pupil: 0.086, 0.064, 0.044
# [subject CCA] sub=42, lfp_macro vs pupil: 0.094, 0.073, 0.051
# [subject CCA] sub=43, lfp_macro vs pupil: 0.090, 0.073, 0.047
# [subject CCA] sub=44, lfp_macro vs pupil: 0.075, 0.055, 0.028
# [subject CCA] sub=41, lfp_micro vs eye_gaze: 0.096, 0.078, 0.056
# [subject CCA] sub=42, lfp_micro vs eye_gaze: 0.206, 0.080, 0.060
# [subject CCA] sub=43, lfp_micro vs eye_gaze: 0.169, 0.073, 0.052
# [subject CCA] sub=44, lfp_micro vs eye_gaze: 0.129, 0.084, 0.057
# [subject CCA] sub=41, lfp_micro vs pupil: 0.101, 0.072, 0.042
# [subject CCA] sub=42, lfp_micro vs pupil: 0.115, 0.100, 0.048
# [subject CCA] sub=43, lfp_micro vs pupil: 0.096, 0.042, 0.022
# [subject CCA] sub=44, lfp_micro vs pupil: 0.086, 0.064, 0.057
# [subject CCA] sub=41, eye_gaze vs pupil: 0.576, 0.238, 0.026
# [subject CCA] sub=42, eye_gaze vs pupil: 0.502, 0.267, 0.057
# [subject CCA] sub=43, eye_gaze vs pupil: 0.399, 0.137, 0.089
# [subject CCA] sub=44, eye_gaze vs pupil: 0.442, 0.171, 0.081

# %%
modality_keys = ["firing_rate", "lfp_macro", "lfp_micro", "eye_gaze", "pupil"]

subject_time_pca_res = new_fusion.run_multimodal_subjectwise_time_trajectory_pca(
    concat_data,
    modality_keys=modality_keys,
    n_components=5,
    sub_col="sub",
    standardize=True,
    verbose=True,
)

time_cca_res = new_fusion.compute_pairwise_time_cca_subjectwise(
    subject_time_pca_res,
    modality_keys=modality_keys,
    n_components=3,
    min_windows=10,
    max_iter=2000,
    verbose=True,
)

new_fusion.plot_time_cca_synergy_matrix(
    time_cca_res,
    modality_keys=modality_keys,
    mode="first",
    title="Time-CCA first canonical correlation"
)
# Out:
# [time-PCA] sub=41, modality=firing_rate, X=(3801, 500, 7), Z=(3801, 500, 5)
# [time-PCA] sub=42, modality=firing_rate, X=(3801, 500, 50), Z=(3801, 500, 5)
# [time-PCA] sub=43, modality=firing_rate, X=(3801, 500, 32), Z=(3801, 500, 5)
# [time-PCA] sub=44, modality=firing_rate, X=(3801, 500, 49), Z=(3801, 500, 5)
# [time-PCA] sub=41, modality=lfp_macro, X=(3801, 500, 96), Z=(3801, 500, 5)
# [time-PCA] sub=42, modality=lfp_macro, X=(3801, 500, 96), Z=(3801, 500, 5)
# [time-PCA] sub=43, modality=lfp_macro, X=(3801, 500, 96), Z=(3801, 500, 5)
# [time-PCA] sub=44, modality=lfp_macro, X=(3801, 500, 96), Z=(3801, 500, 5)
# [time-PCA] sub=41, modality=lfp_micro, X=(3801, 500, 80), Z=(3801, 500, 5)
# [time-PCA] sub=42, modality=lfp_micro, X=(3801, 500, 64), Z=(3801, 500, 5)
# [time-PCA] sub=43, modality=lfp_micro, X=(3801, 500, 80), Z=(3801, 500, 5)
# [time-PCA] sub=44, modality=lfp_micro, X=(3801, 500, 64), Z=(3801, 500, 5)
# [time-PCA] sub=41, modality=eye_gaze, X=(3801, 500, 2), Z=(3801, 500, 2)
# [time-PCA] sub=42, modality=eye_gaze, X=(3801, 500, 2), Z=(3801, 500, 2)
# [time-PCA] sub=43, modality=eye_gaze, X=(3801, 500, 2), Z=(3801, 500, 2)
# [time-PCA] sub=44, modality=eye_gaze, X=(3801, 500, 2), Z=(3801, 500, 2)
# [time-PCA] sub=41, modality=pupil, X=(3801, 500, 1), Z=(3801, 500, 1)
# [time-PCA] sub=42, modality=pupil, X=(3801, 500, 1), Z=(3801, 500, 1)
# [time-PCA] sub=43, modality=pupil, X=(3801, 500, 1), Z=(3801, 500, 1)
# [time-PCA] sub=44, modality=pupil, X=(3801, 500, 1), Z=(3801, 500, 1)
# [time-CCA] sub=41, firing_rate vs lfp_macro, N=3801, T=500, Kc=3, corrs=0.006, 0.005, 0.003
# [time-CCA] sub=42, firing_rate vs lfp_macro, N=3801, T=500, Kc=3, corrs=0.011, 0.006, 0.005
# [time-CCA] sub=43, firing_rate vs lfp_macro, N=3801, T=500, Kc=3, corrs=0.012, 0.005, 0.004
# [time-CCA] sub=44, firing_rate vs lfp_macro, N=3801, T=500, Kc=3, corrs=0.005, 0.008, 0.002
# [time-CCA] sub=41, firing_rate vs lfp_micro, N=3801, T=500, Kc=3, corrs=0.006, 0.005, 0.003
# [time-CCA] sub=42, firing_rate vs lfp_micro, N=3801, T=500, Kc=3, corrs=0.012, 0.011, 0.005
# [time-CCA] sub=43, firing_rate vs lfp_micro, N=3801, T=500, Kc=3, corrs=0.031, 0.008, 0.004
# [time-CCA] sub=44, firing_rate vs lfp_micro, N=3801, T=500, Kc=3, corrs=0.011, 0.008, 0.005
# [time-CCA] sub=41, firing_rate vs eye_gaze, N=3801, T=500, Kc=2, corrs=0.006, 0.003
# [time-CCA] sub=42, firing_rate vs eye_gaze, N=3801, T=500, Kc=2, corrs=0.010, 0.004
# [time-CCA] sub=43, firing_rate vs eye_gaze, N=3801, T=500, Kc=2, corrs=0.011, 0.003
# [time-CCA] sub=44, firing_rate vs eye_gaze, N=3801, T=500, Kc=2, corrs=0.006, 0.003
# [time-CCA] sub=41, firing_rate vs pupil, N=3801, T=500, Kc=1, corrs=0.005
# [time-CCA] sub=42, firing_rate vs pupil, N=3801, T=500, Kc=1, corrs=0.006
# [time-CCA] sub=43, firing_rate vs pupil, N=3801, T=500, Kc=1, corrs=0.008
# [time-CCA] sub=44, firing_rate vs pupil, N=3801, T=500, Kc=1, corrs=0.006
# [time-CCA] sub=41, lfp_macro vs lfp_micro, N=3801, T=500, Kc=3, corrs=0.144, 0.102, 0.090
# [time-CCA] sub=42, lfp_macro vs lfp_micro, N=3801, T=500, Kc=3, corrs=0.399, 0.346, 0.296
# [time-CCA] sub=43, lfp_macro vs lfp_micro, N=3801, T=500, Kc=3, corrs=0.586, 0.472, 0.198
# [time-CCA] sub=44, lfp_macro vs lfp_micro, N=3801, T=500, Kc=3, corrs=0.434, 0.149, 0.048
# [time-CCA] sub=41, lfp_macro vs eye_gaze, N=3801, T=500, Kc=2, corrs=0.049, 0.022
# [time-CCA] sub=42, lfp_macro vs eye_gaze, N=3801, T=500, Kc=2, corrs=0.060, 0.033
# [time-CCA] sub=43, lfp_macro vs eye_gaze, N=3801, T=500, Kc=2, corrs=0.071, 0.028
# [time-CCA] sub=44, lfp_macro vs eye_gaze, N=3801, T=500, Kc=2, corrs=0.079, 0.048
# [time-CCA] sub=41, lfp_macro vs pupil, N=3801, T=500, Kc=1, corrs=0.034
# [time-CCA] sub=42, lfp_macro vs pupil, N=3801, T=500, Kc=1, corrs=0.115
# [time-CCA] sub=43, lfp_macro vs pupil, N=3801, T=500, Kc=1, corrs=0.076
# [time-CCA] sub=44, lfp_macro vs pupil, N=3801, T=500, Kc=1, corrs=0.068
# [time-CCA] sub=41, lfp_micro vs eye_gaze, N=3801, T=500, Kc=2, corrs=0.045, 0.018
# [time-CCA] sub=42, lfp_micro vs eye_gaze, N=3801, T=500, Kc=2, corrs=0.021, 0.015
# [time-CCA] sub=43, lfp_micro vs eye_gaze, N=3801, T=500, Kc=2, corrs=0.020, 0.012
# [time-CCA] sub=44, lfp_micro vs eye_gaze, N=3801, T=500, Kc=2, corrs=0.030, 0.020
# [time-CCA] sub=41, lfp_micro vs pupil, N=3801, T=500, Kc=1, corrs=0.042
# [time-CCA] sub=42, lfp_micro vs pupil, N=3801, T=500, Kc=1, corrs=0.064
# [time-CCA] sub=43, lfp_micro vs pupil, N=3801, T=500, Kc=1, corrs=0.030
# [time-CCA] sub=44, lfp_micro vs pupil, N=3801, T=500, Kc=1, corrs=0.070
# [time-CCA] sub=41, eye_gaze vs pupil, N=3801, T=500, Kc=1, corrs=0.012
# [time-CCA] sub=42, eye_gaze vs pupil, N=3801, T=500, Kc=1, corrs=0.079
# [time-CCA] sub=43, eye_gaze vs pupil, N=3801, T=500, Kc=1, corrs=0.192
# [time-CCA] sub=44, eye_gaze vs pupil, N=3801, T=500, Kc=1, corrs=0.116

# %%
from itertools import combinations

for m1, m2 in combinations(modality_keys, 2):
    new_fusion.plot_time_cca_grandavg_timeseries(
        time_cca_res,
        m1,
        m2,
        comp=0,
        with_sem=True,
    )

    new_fusion.plot_time_cca_mean_timeseries_heatmap(
        time_cca_res,
        m1,
        m2,
    )

# %%
strong_pairs = [
    ("lfp_macro", "lfp_micro"),
    ("lfp_micro", "eye_gaze"),
    ("lfp_macro", "eye_gaze"),
]

# %%
from numpy.linalg import lstsq, eig
from scipy.signal import detrend

def compute_jpca(X, dt):
    """
    X: [T, D]
    dt: scalar
    """
    X = np.asarray(X, dtype=np.float64)

    if X.ndim != 2:
        raise ValueError(f"X must be 2D, got shape={X.shape}")
    if X.shape[0] < 3:
        raise ValueError(f"Need at least 3 time points, got shape={X.shape}")
    if not np.isfinite(dt) or dt <= 0:
        raise ValueError(f"dt must be positive finite, got dt={dt}")

    # 对齐成:
    # X_prev[t] 对应 dX[t] = (X[t+1]-X[t]) / dt
    X_prev = X[:-1]                    # [T-1, D]
    dX = np.diff(X, axis=0) / dt       # [T-1, D]

    # fit: dX = X_prev @ M
    M, _, _, _ = lstsq(X_prev, dX, rcond=None)   # M shape [D, D]

    # 旋转部分
    M_skew = 0.5 * (M - M.T)

    eigvals, eigvecs = eig(M_skew)
    return M, M_skew, eigvals, eigvecs

def project_to_jpca_plane(X, eigvecs, eigvals):
    """
    取虚部最大的那一对特征向量，构造2D jPCA plane
    """
    imag_strength = np.abs(np.imag(eigvals))
    idx = np.argsort(imag_strength)[-2:]

    W = np.real(eigvecs[:, idx])   # [D, 2]
    X_jpca = X @ W                 # [T, 2]
    return X_jpca, W, idx


def plot_jpca_trajectory(X_jpca, modality):
    plt.figure(figsize=(5, 5))
    plt.plot(X_jpca[:, 0], X_jpca[:, 1], linewidth=1)
    plt.scatter(X_jpca[0, 0], X_jpca[0, 1], label="start")
    plt.scatter(X_jpca[-1, 0], X_jpca[-1, 1], label="end")
    plt.xlabel("jPC1")
    plt.ylabel("jPC2")
    plt.title(f"{modality} jPCA plane")
    plt.legend()
    plt.axis("equal")
    plt.show()


def run_jpca_on_result(res, n_input_pc=6):
    X = np.asarray(res["pca_scores"], dtype=np.float64)
    X = detrend(X, axis=0)
    t = np.asarray(res["time"], dtype=np.float64)

    if X.ndim != 2:
        raise ValueError(f"pca_scores must be 2D, got {X.shape}")
    if len(t) != X.shape[0]:
        raise ValueError(f"time length {len(t)} != X rows {X.shape[0]}")
    if len(t) < 3:
        raise ValueError(f"Need at least 3 time points, got {len(t)}")

    # 去掉非有限时间差
    dt_all = np.diff(t)
    dt_all = dt_all[np.isfinite(dt_all) & (dt_all > 0)]
    if len(dt_all) == 0:
        raise ValueError("No valid positive dt found in time axis")
    dt = np.median(dt_all)

    # 限制输入维数
    k = min(n_input_pc, X.shape[1])
    X = X[:, :k]

    # 去掉含nan的行
    good = np.isfinite(X).all(axis=1) & np.isfinite(t)
    X = X[good]
    t = t[good]

    if X.shape[0] < 3:
        raise ValueError(f"Not enough valid rows after cleaning: {X.shape}")

    M, M_skew, eigvals, eigvecs = compute_jpca(X, dt)
    X_jpca, W, idx = project_to_jpca_plane(X, eigvecs, eigvals)

    plot_jpca_trajectory(X_jpca, res["modality"])

    print(f"{res['modality']} | input_dim={k}, T={X.shape[0]}, dt={dt:.6f}")
    print("eigenvalues:", eigvals)
    print("imag parts:", np.imag(eigvals))

    return {
        "X_jpca": X_jpca,
        "eigvals": eigvals,
        "eigvecs": eigvecs,
        "W": W,
        "idx": idx,
        "M": M,
        "M_skew": M_skew,
        "dt": dt,
    }

# %%
jpca_results = {}

for modality, res in results.items():
    if res is None:
        continue

    print("\n====", modality, "====")
    try:
        jpca_results[modality] = run_jpca_on_result(res, n_input_pc=6)
    except Exception as e:
        print(f"[skip] {modality}: {e}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 3
#       1 jpca_results = {}
# ----> 3 for modality, res in results.items():
#       4     if res is None:
#       5         continue
#
# NameError: name 'results' is not defined
